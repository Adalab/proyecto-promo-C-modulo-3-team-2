# %%
import pandas as pd
import numpy as np
import os

# %%
pd.options.display.max_columns = None

# %%
from datetime import datetime

# %%
df_txt= pd.read_csv("data/04-data-txt-col-rename.csv", )
df_txt.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  index       pais          educacion  \
# 0           0             0      0      India  Bachelor’s degree
# 1           1             1      1  Indonesia    Master’s degree
#
#                  ocupacion experiencia l_recomendado  \
# 0                    Other  5-10 years        Python
# 1  Program/Project Manager   20+ years        Python
#
#                                           plataforma        tpu  \
# 0                                           A laptop  2-5 times
# 1  A cloud computing platform (AWS, Azure, GCP, h...      Never
#
#                     i_actual             e_tamanio e_analistas salario_actual  \
# 0  Manufacturing/Fabrication      50-249 employees         3-4  25,000-29,999
# 1  Manufacturing/Fabrication  1000-9,999 employees         1-2  60,000-69,999
#
#   presupuesto_ml_cc big_products_used  \
# 0         $100-$999               NaN
# 1         $0 ($USD)               NaN
#
#                                            tool_ppal         l_utilizado  \
# 0  Local development environments (RStudio, Jupyt...           Python, R
# 1    Advanced statistical software (SPSS, SAS, etc.)   SQL, C, C++, Java
#
#                            adi            hardware  \
# 0                  Vim / Emacs  Google Cloud TPUs
# 1   Notepad++,Jupyter Notebook                None
#
#                                        visualizacion  \
# 0   Matplotlib ,Seaborn ,Ggplot / ggplot2 ,Shiny ...
# 1                                        Matplotlib
#
#                                        e_actividades  big_products
# 0   None of these activities are an important par...   PostgreSQL
# 1   Build and/or run the data infrastructure that...           NaN

# %%
# shape

df_txt.shape
# Out:
# (25973, 23)

# %%
df_txt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25973 entries, 0 to 25972
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         25973 non-null  int64
#  1   Unnamed: 0.1       25973 non-null  int64
#  2   index              25973 non-null  int64
#  3   pais               25973 non-null  object
#  4   educacion          25973 non-null  object
#  5   ocupacion          25973 non-null  object
#  6   experiencia        25973 non-null  object
#  7   l_recomendado      24940 non-null  object
#  8   plataforma         24720 non-null  object
#  9   tpu                24403 non-null  object
#  10  i_actual           16325 non-null  object
#  11  e_tamanio          16251 non-null  object
#  12  e_analistas        16126 non-null  object
#  13  salario_actual     15391 non-null  object
#  14  presupuesto_ml_cc  15183 non-null  object
#  15  big_products_used  4656 non-null   object
#  16  tool_ppal          18489 non-null  object
#  17  l_utilizado        24941 non-null  object
#  18  adi                24934 non-null  object
#  19  hardware           24582 non-null  object
#  20  visualizacion      23970 non-null  object
#  21  e_actividades      15635 non-null  object
#  22  big_products       9484 non-null   object
# dtypes: int64(3), object(20)
# memory usage: 4.6+ MB

# %% [markdown]
# ojo: salario, cambiar a número

# %%
df_txt.describe().T
# Out:
#                 count     mean          std  min     25%      50%      75%  \
# Unnamed: 0    25973.0  12986.0  7497.903607  0.0  6493.0  12986.0  19479.0
# Unnamed: 0.1  25973.0  12986.0  7497.903607  0.0  6493.0  12986.0  19479.0
# index         25973.0  12986.0  7497.903607  0.0  6493.0  12986.0  19479.0
#
#                   max
# Unnamed: 0    25972.0
# Unnamed: 0.1  25972.0
# index         25972.0

# %%
df_txt.describe(include="object")
# Out:
#          pais        educacion ocupacion experiencia l_recomendado plataforma  \
# count   25973            25973     25973       25973         24940      24720
# unique     66                7        15           7            13          6
# top     India  Master’s degree   Student   1-3 years        Python   A laptop
# freq     7434            10132      6804        7874         20213      16231
#
#           tpu              i_actual       e_tamanio e_analistas  \
# count   24403                 16325           16251       16126
# unique      5                    18               5           7
# top     Never  Computers/Technology  0-49 employees         1-2
# freq    16457                  4079            5055        3642
#
#        salario_actual presupuesto_ml_cc big_products_used  \
# count           15391             15183              4656
# unique             26                 6                20
# top            $0-999         $0 ($USD)            MySQL
# freq             3369              5903              1110
#
#                                                 tool_ppal l_utilizado  \
# count                                               18489       24941
# unique                                                  6         825
# top     Basic statistical software (Microsoft Excel, G...      Python
# freq                                                 7246        4740
#
#                      adi hardware          visualizacion  \
# count              24934    24582                  23970
# unique              1330       26                    467
# top     Jupyter Notebook     None   Matplotlib ,Seaborn
# freq                2341    13234                   5697
#
#                                             e_actividades big_products
# count                                               15635         9484
# unique                                                 96         1558
# top     Analyze and understand data to influence produ...         None
# freq                                                 2891         2297

# %%
df_txt.describe(include="object").T
# Out:
#                    count unique  \
# pais               25973     66
# educacion          25973      7
# ocupacion          25973     15
# experiencia        25973      7
# l_recomendado      24940     13
# plataforma         24720      6
# tpu                24403      5
# i_actual           16325     18
# e_tamanio          16251      5
# e_analistas        16126      7
# salario_actual     15391     26
# presupuesto_ml_cc  15183      6
# big_products_used   4656     20
# tool_ppal          18489      6
# l_utilizado        24941    825
# adi                24934   1330
# hardware           24582     26
# visualizacion      23970    467
# e_actividades      15635     96
# big_products        9484   1558
#
#                                                                  top   freq
# pais                                                           India   7434
# educacion                                            Master’s degree  10132
# ocupacion                                                    Student   6804
# experiencia                                                1-3 years   7874
# l_recomendado                                                 Python  20213
# plataforma                                                  A laptop  16231
# tpu                                                            Never  16457
# i_actual                                        Computers/Technology   4079
# e_tamanio                                             0-49 employees   5055
# e_analistas                                                      1-2   3642
# salario_actual                                                $0-999   3369
# presupuesto_ml_cc                                          $0 ($USD)   5903
# big_products_used                                             MySQL    1110
# tool_ppal          Basic statistical software (Microsoft Excel, G...   7246
# l_utilizado                                                   Python   4740
# adi                                                 Jupyter Notebook   2341
# hardware                                                        None  13234
# visualizacion                                   Matplotlib ,Seaborn    5697
# e_actividades      Analyze and understand data to influence produ...   2891
# big_products                                                    None   2297

# %%
# Pensar agrupar por continentes
df_txt["pais"].value_counts()
# Out:
# India                       7434
# United States of America    2650
# Other                       1270
# Japan                        921
# China                        814
#                             ...
# Norway                        45
# Kazakhstan                    45
# Algeria                       44
# Ethiopia                      43
# Iraq                          43
# Name: pais, Length: 66, dtype: int64

# %%
# Pensar si acotar la investigacion a analistas de datos únicamente
df_txt["ocupacion"].value_counts()
# Out:
# Student                         6804
# Data Scientist                  3616
# Software Engineer               2449
# Other                           2393
# Data Analyst                    2301
# Currently not employed          1986
# Research Scientist              1538
# Machine Learning Engineer       1499
# Business Analyst                 968
# Program/Project Manager          849
# Data Engineer                    668
# Product Manager                  319
# Statistician                     313
# DBA/Database Engineer            171
# Developer Relations/Advocacy      99
# Name: ocupacion, dtype: int64

# %%
#media de salario mundial de un data analist
df_txt["salario_actual"].value_counts()
# Out:
# $0-999              3369
# 1,000-1,999          969
# 10,000-14,999        950
# 30,000-39,999        741
# 100,000-124,999      725
# 5,000-7,499          699
# 50,000-59,999        697
# 40,000-49,999        688
# 20,000-24,999        587
# 2,000-2,999          575
# 15,000-19,999        573
# 7,500-9,999          552
# 60,000-69,999        551
# 25,000-29,999        470
# 70,000-79,999        464
# 4,000-4,999          456
# 150,000-199,999      392
# 80,000-89,999        391
# 3,000-3,999          380
# 125,000-149,999      379
# 90,000-99,999        350
# 200,000-249,999      177
# 300,000-499,999       91
# 250,000-299,999       75
# >$1,000,000           58
# $500,000-999,999      32
# Name: salario_actual, dtype: int64

# %%
df_txt["salario_actual"].unique()
# Out:
# array(['25,000-29,999', '60,000-69,999', '$0-999', '30,000-39,999', nan,
#        '15,000-19,999', '70,000-79,999', '2,000-2,999', '10,000-14,999',
#        '5,000-7,499', '20,000-24,999', '1,000-1,999', '100,000-124,999',
#        '7,500-9,999', '4,000-4,999', '40,000-49,999', '50,000-59,999',
#        '3,000-3,999', '300,000-499,999', '200,000-249,999',
#        '125,000-149,999', '250,000-299,999', '80,000-89,999',
#        '90,000-99,999', '150,000-199,999', '>$1,000,000',
#        '$500,000-999,999'], dtype=object)

# %%
df_txt.isnull().sum()
# Out:
# Unnamed: 0               0
# Unnamed: 0.1             0
# index                    0
# pais                     0
# educacion                0
# ocupacion                0
# experiencia              0
# l_recomendado         1033
# plataforma            1253
# tpu                   1570
# i_actual              9648
# e_tamanio             9722
# e_analistas           9847
# salario_actual       10582
# presupuesto_ml_cc    10790
# big_products_used    21317
# tool_ppal             7484
# l_utilizado           1032
# adi                   1039
# hardware              1391
# visualizacion         2003
# e_actividades        10338
# big_products         16489
# dtype: int64

# %%
df_txt.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25968    False
# 25969    False
# 25970    False
# 25971    False
# 25972    False
# Length: 25973, dtype: bool

# %%
# salario y país
df_india = df_txt[df_txt["pais"] == "India"]

# %%
df_india[df_india["salario_actual"] > '5,000-7,499']
# Out:
#        Unnamed: 0  Unnamed: 0.1  index   pais          educacion  \
# 30             30            30     30  India  Bachelor’s degree
# 101           101           101    101  India    Master’s degree
# 122           122           122    122  India    Master’s degree
# 201           201           201    201  India    Master’s degree
# 300           300           300    300  India    Master’s degree
# ...           ...           ...    ...    ...                ...
# 25831       25831         25831  25831  India  Bachelor’s degree
# 25893       25893         25893  25893  India    Master’s degree
# 25903       25903         25903  25903  India  Bachelor’s degree
# 25911       25911         25911  25911  India  Bachelor’s degree
# 25924       25924         25924  25924  India    Master’s degree
#
#                      ocupacion  experiencia l_recomendado  \
# 30                       Other    1-3 years        Python
# 101          Software Engineer    1-3 years        Python
# 122    Program/Project Manager  10-20 years        Python
# 201             Data Scientist  10-20 years             C
# 300         Research Scientist    3-5 years        Python
# ...                        ...          ...           ...
# 25831             Data Analyst    3-5 years        Python
# 25893                    Other    3-5 years        Python
# 25903           Data Scientist    1-3 years        Python
# 25911           Data Scientist    1-3 years        Python
# 25924        Software Engineer    20+ years        Python
#
#                                               plataforma         tpu  \
# 30                                              A laptop       Never
# 101                                             A laptop       Never
# 122                        A personal computer / desktop       Never
# 201                                             A laptop       Never
# 300    A cloud computing platform (AWS, Azure, GCP, h...        Once
# ...                                                  ...         ...
# 25831                                           A laptop       Never
# 25893                                           A laptop       Never
# 25903                                           A laptop  6-25 times
# 25911                                           A laptop       Never
# 25924                                           A laptop       Never
#
#                                    i_actual                 e_tamanio  \
# 30                     Computers/Technology      1000-9,999 employees
# 101                    Computers/Technology  10,000 or more employees
# 122                    Computers/Technology  10,000 or more employees
# 201    Online Business/Internet-based Sales      1000-9,999 employees
# 300                    Computers/Technology      1000-9,999 employees
# ...                                     ...                       ...
# 25831  Online Business/Internet-based Sales  10,000 or more employees
# 25893                  Computers/Technology  10,000 or more employees
# 25903                Medical/Pharmaceutical  10,000 or more employees
# 25911                   Academics/Education            0-49 employees
# 25924                         Energy/Mining            0-49 employees
#
#       e_analistas salario_actual presupuesto_ml_cc      big_products_used  \
# 30              0    7,500-9,999         $100-$999                    NaN
# 101           5-9    7,500-9,999         $0 ($USD)                    NaN
# 122           20+  60,000-69,999   $10,000-$99,999  Microsoft SQL Server
# 201           20+  60,000-69,999      $1000-$9,999                 MySQL
# 300           5-9    7,500-9,999         $0 ($USD)                    NaN
# ...           ...            ...               ...                    ...
# 25831         20+    7,500-9,999   $10,000-$99,999                    NaN
# 25893         1-2    7,500-9,999      $1000-$9,999  Microsoft SQL Server
# 25903         20+    7,500-9,999   $10,000-$99,999                    NaN
# 25911           0    >$1,000,000         $100-$999            Amazon RDS
# 25924         3-4  50,000-59,999      $1000-$9,999                    NaN
#
#                                                tool_ppal  \
# 30     Local development environments (RStudio, Jupyt...
# 101                                                  NaN
# 122    Local development environments (RStudio, Jupyt...
# 201    Local development environments (RStudio, Jupyt...
# 300                                                Other
# ...                                                  ...
# 25831  Basic statistical software (Microsoft Excel, G...
# 25893  Basic statistical software (Microsoft Excel, G...
# 25903  Basic statistical software (Microsoft Excel, G...
# 25911  Basic statistical software (Microsoft Excel, G...
# 25924  Basic statistical software (Microsoft Excel, G...
#
#                   l_utilizado  \
# 30                     Python
# 101            Python, MATLAB
# 122    Python, SQL, C++, Java
# 201                    Python
# 300        Python, C++, Other
# ...                       ...
# 25831      Python, SQL, Other
# 25893       Python, SQL, Bash
# 25903       Python, SQL, Java
# 25911       Python, C++, Java
# 25924               Python, C
#
#                                                      adi  \
# 30         Visual Studio Code (VSCode) ,Jupyter Notebook
# 101         RStudio , Notepad++,MATLAB ,Jupyter Notebook
# 122    Visual Studio ,Visual Studio Code (VSCode) ,Py...
# 201    Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 300           Sublime Text, Vim / Emacs,Jupyter Notebook
# ...                                                  ...
# 25831                 Spyder, Notepad++,Jupyter Notebook
# 25893         Visual Studio , Notepad++,Jupyter Notebook
# 25903  Jupyter (JupyterLab, Jupyter Notebooks, etc) ,...
# 25911      Visual Studio Code (VSCode) ,Jupyter Notebook
# 25924                                      Spyder, Other
#
#                                hardware  \
# 30                                 None
# 101                                None
# 122                        NVIDIA GPUs
# 201                                None
# 300                                None
# ...                                 ...
# 25831                              None
# 25893                              None
# 25903   NVIDIA GPUs ,Google Cloud TPUs
# 25911                              None
# 25924                              None
#
#                                            visualizacion  \
# 30                                  Matplotlib ,Seaborn
# 101                                          Matplotlib
# 122     Matplotlib ,Seaborn ,Plotly / Plotly Express ...
# 201                                 Matplotlib ,Seaborn
# 300                                                 None
# ...                                                  ...
# 25831                                        Matplotlib
# 25893                                        Matplotlib
# 25903   Matplotlib ,Seaborn ,Plotly / Plotly Express ...
# 25911             Matplotlib ,Seaborn ,Ggplot / ggplot2
# 25924                                        Matplotlib
#
#                                            e_actividades  \
# 30      None of these activities are an important par...
# 101                                                Other
# 122    Analyze and understand data to influence produ...
# 201    Analyze and understand data to influence produ...
# 300    Analyze and understand data to influence produ...
# ...                                                  ...
# 25831  Analyze and understand data to influence produ...
# 25893  Analyze and understand data to influence produ...
# 25903   Build and/or run a machine learning service t...
# 25911  Analyze and understand data to influence produ...
# 25924  Analyze and understand data to influence produ...
#
#                                             big_products
# 30                                                  None
# 101                                                  NaN
# 122     PostgreSQL , Oracle Database , MongoDB , Micr...
# 201                   MySQL , Microsoft Azure Cosmos DB
# 300                                                  NaN
# ...                                                  ...
# 25831                              Microsoft SQL Server
# 25893   Microsoft SQL Server , Microsoft Azure SQL Da...
# 25903                                           MongoDB
# 25911   Amazon Redshift , Amazon Aurora , Amazon RDS ...
# 25924                                             MySQL
#
# [403 rows x 23 columns]
