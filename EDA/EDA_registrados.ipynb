# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
import calendar

from datetime import datetime
from scipy import stats
import researchpy as rp
from scipy.stats import levene
from sklearn.preprocessing import MinMaxScaler
import math

warnings.filterwarnings("ignore")
pd.options.display.max_columns = None

plt.rcParams["figure.figsize"] = (10,8)

# %% [markdown]
# Hacemos un EDA de cada df

# %%
df = pd.read_csv("../data/01_bikes_registrados.csv", index_col = 0 )
df.head(2)
# Out:
#         fecha estacion  año  mes  vacaciones  dia_semana laborable  clima  \
# 0  2018-01-01   winter    0    1           1           1        NO      2
# 1  2018-01-02   winter    0    1           0           2        SI      2
#
#    temperatura  sensacion_termica  humedad     viento  registrados
# 0    14.110847           18.18125  80.5833  10.749882          654
# 1    14.902598           17.68695  69.6087  16.652113          670

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 729
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fecha              730 non-null    object
#  1   estacion           730 non-null    object
#  2   año                730 non-null    int64
#  3   mes                730 non-null    int64
#  4   vacaciones         730 non-null    int64
#  5   dia_semana         730 non-null    int64
#  6   laborable          730 non-null    object
#  7   clima              730 non-null    int64
#  8   temperatura        730 non-null    float64
#  9   sensacion_termica  730 non-null    float64
#  10  humedad            730 non-null    float64
#  11  viento             730 non-null    float64
#  12  registrados        730 non-null    int64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 79.8+ KB

# %%
df.shape
# Out:
# (730, 13)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# fecha                0
# estacion             0
# año                  0
# mes                  0
# vacaciones           0
# dia_semana           0
# laborable            0
# clima                0
# temperatura          0
# sensacion_termica    0
# humedad              0
# viento               0
# registrados          0
# dtype: int64

# %%
df["vacaciones"] = df["vacaciones"].astype("category")

# %%
def detectar_outliers(lista_columnas, dataframe):
    dicc_indices = {} # creamos un diccionario donde almacenaremos índices de los outliers
    # iteramos por la lista de las columnas numéricas de nuestro dataframe
    for col in lista_columnas:
        #calculamos los cuartiles Q1 y Q3
        Q1 = np.nanpercentile(df[col], 25)
        Q3 = np.nanpercentile(df[col], 75)
        # calculamos el rango intercuartil
        IQR = Q3 - Q1
        # calculamos los límites
        outlier_step = 1.5 * IQR
        # filtramos nuestro dataframe para indentificar los outliers
        outliers_data = dataframe[(dataframe[col] < Q1 - outlier_step) | (dataframe[col] > Q3 + outlier_step)]
        if outliers_data.shape[0] > 0: # chequeamos si nuestro dataframe tiene alguna fila.
            dicc_indices[col] = (list(outliers_data.index)) # si tiene fila es que hay outliers y por lo tanto lo añadimos a nuestro diccionario
    return dicc_indices

# %%
numericas = df.select_dtypes(include = np.number).drop(['año', 'mes', 'dia_semana'], axis =1)
columnas = numericas.columns

# %%
indices = detectar_outliers(columnas, numericas)

# %%
fig, axes = plt.subplots(3, 2, figsize=(15,10))

axes = axes.flat

for indice, columna in enumerate(numericas.columns):
    sns.boxplot(x = numericas[columna], data = df, ax=axes[indice], color = "turquoise"); # para trazar una línea de densidad
    
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize =(8,4))

fig = sns.histplot(x='registrados', data = df, hue='laborable', palette=sns.blend_palette(['turquoise','orange'],2 ))

# establecemos el nombre de los ejes, pero recordad que esto no es obligatorio ya que Seaborn nos los genera automaticamente
fig.set(ylabel='Conteo', xlabel = 'Alquileres')

# Ponemos título a  la gráfica
fig.set_title('')

# mostramos la gráfica
plt.show()

# %% [markdown]
# De este grafico podemos ver que los días que más bicis se alquilan son los días laborables.

# %%
plt.figure(figsize =(8,4))

fig = sns.barplot(x='mes', y = 'registrados', data = df ,palette=sns.blend_palette(['turquoise','orange'] ))

# establecemos el nombre de los ejes, pero recordad que esto no es obligatorio ya que Seaborn nos los genera automaticamente
fig.set(ylabel='Alquileres casuales', xlabel = 'Mes')

# Ponemos título a  la gráfica
fig.set_title('')

# mostramos la gráfica
plt.show()

# %%
sns.boxplot(data=df, y= "registrados", x = "mes", palette=sns.blend_palette(['turquoise','orange'] ))
# Out:
# <AxesSubplot:xlabel='mes', ylabel='registrados'>

# %% [markdown]
# ---
#
# ## Miramos las asunciones
#
# ---

# %% [markdown]
# ### Testeamos la normalidad de la var respuesta

# %%
sns.displot(df["registrados"], kde=True)

# %%
stats.shapiro(df["registrados"])
# Out:
# ShapiroResult(statistic=0.98438560962677, pvalue=5.023745757171127e-07)

# %% [markdown]
# Los datos no son normales porque son menores de 0.05

# %% [markdown]
# ### Procedemos a normalizar la variable respuesta

# %% [markdown]
# Raiz cuadrada

# %%
df["registrados_raiz"] = df["registrados"].apply(lambda x: math.sqrt(x))

# %%
sns.displot(df["registrados"], kde=True)

# %%
stats.shapiro(df["registrados_raiz"])
# Out:
# ShapiroResult(statistic=0.9734106659889221, pvalue=2.97543378824372e-10)

# %% [markdown]
# Observamos que nuestro p_valor > 0.05 nuestros datos NO son normales.

# %% [markdown]
# Box_cox

# %%
df['registrados_box'], lambda_ajustada = stats.boxcox(df['registrados'])

# %%
sns.displot(df["registrados_box"], kde=True)

# %%
stats.shapiro(df["registrados_box"])
# Out:
# ShapiroResult(statistic=0.9854231476783752, pvalue=1.1639369859040016e-06)

# %% [markdown]
# Observamos que nuestro p_valor > 0.05 nuestros datos NO son normales.

# %%
df["registrados_log"] = df["registrados"].apply(lambda x: np.log(x) if x > 0 else 0)

# %%
sns.displot(df["registrados_log"], kde=True)

# %%
stats.shapiro(df["registrados_log"])
# Out:
# ShapiroResult(statistic=0.8750768303871155, pvalue=9.986205976410893e-24)

# %% [markdown]
# Observamos que nuestro p_valor > 0.05 nuestros datos NO son normales.

# %% [markdown]
# Min Scaler

# %%
minmax = MinMaxScaler()
minmax.fit(df[['registrados']])
# Out:
# MinMaxScaler()

# %%
X_normalizadas = minmax.transform(df[['registrados']])

# %%
X_normalizadas.min(axis=0)
# Out:
# array([0.])

# %%
X_normalizadas.max(axis=0)
# Out:
# array([1.])

# %%
numericas_minmax= pd.DataFrame(X_normalizadas, columns= ['registrados'])

# %%
df['registrados_min_max'] = numericas_minmax

# %%
sns.displot(df["registrados_min_max"], kde=True)

# %%
stats.shapiro(df["registrados_min_max"])
# Out:
# ShapiroResult(statistic=0.98438560962677, pvalue=5.023745757171127e-07)

# %% [markdown]
# Observamos que nuestro p_valor > 0.05 nuestros datos NO son normales.

# %% [markdown]
# ### No conseguimos normalizar la variable respuesta con ningún método así que pasamos a tratar los datos para hacer el método mediante decision tree

# %%
#Borramos las columnas que no necesitamos 
df.drop(['registrados_raiz','registrados_box', 'registrados_log', 'registrados_min_max'], axis=1, inplace=True )

# %%
df.head(2)
# Out:
#         fecha estacion  año  mes vacaciones  dia_semana laborable  clima  \
# 0  2018-01-01   winter    0    1          1           1        NO      2
# 1  2018-01-02   winter    0    1          0           2        SI      2
#
#    temperatura  sensacion_termica  humedad     viento  registrados
# 0    14.110847           18.18125  80.5833  10.749882          654
# 1    14.902598           17.68695  69.6087  16.652113          670

# %% [markdown]
# ---
#
# ### Análisis de correlación
#
# ---

# %%
sns.heatmap(df.corr(), 
            cmap = "cubehelix", 
           annot = True);

# %%
df.corr()
# Out:
#                             año           mes  dia_semana     clima  \
# año                1.000000e+00 -5.162656e-16    0.000684 -0.050322
# mes               -5.162656e-16  1.000000e+00    0.006080  0.045613
# dia_semana         6.843499e-04  6.079650e-03    1.000000  0.042703
# clima             -5.032247e-02  4.561335e-02    0.042703  1.000000
# temperatura        4.878919e-02  2.190833e-01    0.029929 -0.119503
# sensacion_termica  4.721519e-02  2.264302e-01    0.023235 -0.120559
# humedad           -1.125471e-01  2.249368e-01   -0.034223  0.590277
# viento            -1.162435e-02 -2.080131e-01   -0.011361  0.039769
# registrados        5.969106e-01  2.919516e-01    0.148473 -0.259025
#
#                    temperatura  sensacion_termica   humedad    viento  \
# año                   0.048789           0.047215 -0.112547 -0.011624
# mes                   0.219083           0.226430  0.224937 -0.208013
# dia_semana            0.029929           0.023235 -0.034223 -0.011361
# clima                -0.119503          -0.120559  0.590277  0.039769
# temperatura           1.000000           0.991696  0.128565 -0.158186
# sensacion_termica     0.991696           1.000000  0.141512 -0.183876
# humedad               0.128565           0.141512  1.000000 -0.248506
# viento               -0.158186          -0.183876 -0.248506  1.000000
# registrados           0.539436           0.543678 -0.089212 -0.217914
#
#                    registrados
# año                   0.596911
# mes                   0.291952
# dia_semana            0.148473
# clima                -0.259025
# temperatura           0.539436
# sensacion_termica     0.543678
# humedad              -0.089212
# viento               -0.217914
# registrados           1.000000

# %% [markdown]
# Observamos que temperatura y sensación térmica correlacionan de manera casi total, por lo tanto lo consideramos información redundante y decidimos eliminar una. Vemos más decimales con el df para valorar y vemos que sensacion térmica correlaciona mas.

# %%
sns.pairplot(df)

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 2, figsize = (10, 8))
axes = axes.flat
lista_columnas = ['sensacion_termica', 'temperatura', 'humedad', 'viento']
for i, colum in enumerate(lista_columnas):
    sns.regplot(
        x = df[colum],
        y = df["registrados"],
        color = "orange",
        marker = ".",
        scatter_kws = {"alpha": 0.6},
        line_kws = {"color": "red", "alpha": 0.7 },
        ax = axes[i])
    axes[i].set_title(f"Registrados vs {colum}")
    axes[i].set_xlabel("")
    axes[i].set_ylabel("")
fig.tight_layout();

# %%
#Variables que no nos aportan para nuestro modelo o que son redundantes, eliminamos
df.drop(["temperatura"], axis = 1, inplace = True)

# %%
df.to_csv("../data/02_registrados_limpio.csv")
